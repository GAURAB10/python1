# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Read the online file by the URL provides above, and assign it to variable "df"
other_path1 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/CATAGORY_ITEM_TOTAL.xlsx"
other_path2 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/DAY_ITEM_TOTAL.xlsx"
other_path3 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/HOUR_ITEM_TOTAL.xlsx"
other_path4 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/MONTH_ITEM_TOTAL.xlsx"
other_path5 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/STORE_DAY_ITEM_0204.xlsx"
other_path6 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/STORE_ITEM_TRANS_AREA_TOTAL.xlsx"
other_path7 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/TOTAL_VISITOR_FOOD_AREA_0204_TBR.xlsx"
other_path8 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/VISITOR_FOOD_TRANS_0204_TBR.xlsx"
other_path9 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/NORTH.xlsx"
other_path10 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/MIDDLE.xlsx"
other_path11 = "C:/Users/IBM_ADMIN/Desktop/DATA_SCIENCE/SOUTH.xlsx"

# %%
df1 = pd.read_excel(other_path1)
df2 = pd.read_excel(other_path2)
df3 = pd.read_excel(other_path3)
df4 = pd.read_excel(other_path4)
df5 = pd.read_excel(other_path5)
df6 = pd.read_excel(other_path6)
df7 = pd.read_excel(other_path7)
df8 = pd.read_excel(other_path8)
df9 = pd.read_excel(other_path9)
df10 = pd.read_excel(other_path10)
df11= pd.read_excel(other_path11)

# %%
df1.head(2)
# Out:
#       CATEGORY  TOTAL_ITEM
# 0  Layer-glued     21784.0
# 1        Paper    682290.0

# %%
#to put the labels
plt.figure(figsize=(20,4))
plt.ylabel('Count', fontsize=24)
plt.xlabel('PRODUCT CATAGORY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("PRODUCT CATAGORY SOLD", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df1.groupby("TOTAL_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TOTAL_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df1['TOTAL_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df1['TOTAL_ITEM'])-0.1
#barplot horizontal
g=sns.barplot(x='CATEGORY', y ='TOTAL_ITEM',data=groupedvalues,  palette=np.array(pal[::-1])[rank])
#plt.xlim(minLim,maxLim)
#plt.xticks(np.arange(minLim, 10, 10))
#remove labels

# %%
#to put the labels
plt.figure(figsize=(20,4))
plt.ylabel('Count', fontsize=24)
plt.xlabel('PRODUCT CATAGORY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("PRODUCT CATAGORY SOLD", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df1.groupby("TOTAL_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TOTAL_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df1['TOTAL_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df1['TOTAL_ITEM'])-0.1
#barplot horizontal
g=sns.barplot(x='CATEGORY', y ='TOTAL_ITEM',data=groupedvalues)
#plt.xlim(minLim,maxLim)
#plt.xticks(np.arange(minLim, 10, 10))
#remove labels

# %%
#to put the labels
plt.figure(figsize=(20,4))
plt.ylabel('Count', fontsize=24)
plt.xlabel('PRODUCT CATAGORY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("PRODUCT CATAGORY SOLD", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df1.groupby("TOTAL_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TOTAL_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df1['TOTAL_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df1['TOTAL_ITEM'])-0.1
#barplot horizontal
g=sns.barplot(x='CATEGORY', y ='TOTAL_ITEM',data=df1)

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,6))

df1 ['TOTAL_ITEM'].plot(kind='bar')
plt.title('pi plot')
plt.ylabel('Count', fontsize=12)
plt.xlabel('PRODUCT CATEGORY', fontsize=12)
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("CATAGORY AND ITEM", fontsize=15)
plt.show()

# %%
df2.head()
# Out:
#    DAY    TOTAL_ITEM
# 0    1  3.256239e+06
# 1    2  1.844699e+06
# 2    3  1.841489e+06
# 3    4  1.966829e+06
# 4    5  1.899753e+06

# %%
#to put the labels
plt.figure(figsize=(20,4))
plt.ylabel('TOTAL_ITEM', fontsize=24)
plt.xlabel('DAY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("ITEM SOLD DAYWISE, SUNDAY= 1;SATURDAY=7", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df2.groupby("TOTAL_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TOTAL_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df2['TOTAL_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df2['TOTAL_ITEM'])-0.1
#barplot horizontal
g=sns.barplot(x='DAY', y ='TOTAL_ITEM',data=df2)

# %%
# autopct create %, start angle represent starting point
df2['TOTAL_ITEM'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
plt.figure(figsize=(20,10))
df2['TOTAL_ITEM'].plot(kind='pie')
plt.title('pi plot')
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-294-26a2bb0a2954> in <module>
#       2 df2['TOTAL_ITEM'].plot(kind='pie')
#       3 plt.title('pi plot')
# ----> 4 plt.pie(sizes, labels=labels,
#       5         autopct='%1.1f%%', startangle=200)
#       6 plt.title("Departments distribution", fontsize=15)
#
# NameError: name 'sizes' is not defined

# %%
dff = df2[['DAY', 'TOTAL_ITEM']]

# %%
dff.head()
# Out:
#    DAY    TOTAL_ITEM
# 0    1  3.256239e+06
# 1    2  1.844699e+06
# 2    3  1.841489e+06
# 3    4  1.966829e+06
# 4    5  1.899753e+06

# %%
df3.head()
# Out:
#    HOUR  SOLD_ITEM
# 0     0        2.0
# 1     5        5.0
# 2     6     2762.0
# 3     7    23902.0
# 4     8    41858.0

# %%
#to put the labels
plt.figure(figsize=(20,6))
plt.ylabel('SOLD_ITEM', fontsize=24)
plt.xlabel('HOUR OF DAY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("ITEM SOLD PER HOUR OF A DAY", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df3.groupby("SOLD_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["SOLD_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df3['SOLD_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df3['SOLD_ITEM'])-0.1
#barplot horizontal
g=sns.barplot(x='HOUR', y ='SOLD_ITEM',data=df3)

# %%
df4.head()
# Out:
#         DATE          ITEM
# 0 2019-02-01  5.498638e+05
# 1 2019-02-02  1.041894e+06
# 2 2019-02-03  7.332140e+05
# 3 2019-02-04  3.774254e+05
# 4 2019-02-05  3.888323e+05

# %%
#to put the labels
plt.figure(figsize=(20,8))
plt.ylabel('ITEM', fontsize=24)
plt.xlabel('DATE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("ITEM SOLD PER DAY IN FEBRUARY 19", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df4.groupby("ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df4['ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df4['ITEM'])-0.1
#barplot horizontal
g=sns.barplot(x='DATE', y ='ITEM',data=df4)

# %%
# for this code need to put data in row wise.
df1.plot(kind='bar', figsize=(10, 10))

plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot

plt.show()

# %%
df5.head()
# Out:
#    BU_CODE  DAY_WEEK  TOTAL_ITEM_QTY
# 0       12         1      390315.722
# 1       14         1      223620.600
# 2       17         1      141673.025
# 3       19         1      288959.964
# 4       20         1      149287.200

# %%
#to put the labels
plt.figure(figsize=(20,4))
plt.ylabel('TOTAL_ITEM_QTY', fontsize=24)
plt.xlabel('BU_CODE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("ITEMS SOLD IN DIFFERENT STORE", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df5.groupby("TOTAL_ITEM_QTY").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TOTAL_ITEM_QTY"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df5['TOTAL_ITEM_QTY'].describe())
#set limits
maxLim=1000000
minLim=min(df5['TOTAL_ITEM_QTY'])-0.4
#barplot horizontal
g=sns.barplot(x='BU_CODE', y ='TOTAL_ITEM_QTY',data=df5)
# Out:
# C:\Users\IBM_ADMIN\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df6.head(6)
# Out:
#    STORE   TOTAL_ITEM   TRANSACTION     STORE_AREA  TRANS_ITEM  25AREA_ITEM  \
# 0     12  1989944.821  1.144386e+07  355304.250000    5.750842     4.463745
# 1     14  1008111.230  5.678263e+06  306497.535714    5.632576     7.600787
# 2     17   800744.376  4.582415e+06  384133.571429    5.722695    11.993015
# 3     19  1485652.806  8.687772e+06  230928.250000    5.847781     3.885973
# 4     20   842467.814  4.601102e+06  229246.500000    5.461458     6.802827
# 5     53   690008.076  3.635285e+06  156175.857143    5.268468     5.658479
#
#    TRANS_AREA
# 0   32.208618
# 1   18.526294
# 2   11.929224
# 3   37.621087
# 4   20.070546
# 5   23.276872

# %%
##DEFINE SIZE
plt.figure(figsize=(18,8))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("COMPARATIVE STUDY ON TRANSACTION, ITEM AND AREA LEVEL", fontsize=12)


N=20
y1=df6["TRANS_ITEM"]
y2=df6["25AREA_ITEM"]
y3=df6["TRANS_AREA"]
ind=np.arange(N)
p1=plt.bar(ind,y1)
p2=plt.bar(ind,y2,bottom=y1)
p3=plt.bar(ind,y3,bottom=y2)
plt.ylabel("")
plt.xlabel("STORE")
plt.xticks(ind,df6["STORE"])
plt.legend(['AVERAGE ITEM COST','AVG AREA REQUIRED FOR 1 ITEM','TRANSACTION PER unit AREA'])
plt.show()

# %%
#to put the labels
import matplotlib.patches as mpatches
##DEFINE SIZE
plt.figure(figsize=(20,9))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("COMPARATIVE STUDY ON TRANSACTION, ITEM AND AREA LEVEL", fontsize=20)


plt.stackplot(df6["STORE"],[df6["TRANS_ITEM"],df6["25AREA_ITEM"],df6["TRANS_AREA"]],colors=['#37b85d','#73b837','#adc61b'])
# for colour code
######
plt.legend([mpatches.Patch(color='#37b85d'),  
            mpatches.Patch(color='#73b837'), 
            mpatches.Patch(color='#adc61b')], 
           ['AVERAGE ITEM COST','AVG AREA REQUIRED PER ITEM','TRANSACTION PER AREA'])
plt.show()

# %%
#to put the labels
plt.figure(figsize=(20,3))
plt.ylabel('TRANSACTION VALUE PER ITEM', fontsize=24)
plt.xlabel('STORE NUMBER', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("AVERAGE ITEM PRICE PER STORE", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df6.groupby("TRANS_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TRANS_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df6['TRANS_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df6['TRANS_ITEM'])-0.4
#barplot horizontal
g=sns.barplot(x='STORE', y ='TRANS_ITEM',data=df6)

# %%
#to put the labels
plt.figure(figsize=(20,3))
plt.ylabel('TRANS_AREA', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("IN STORES TRANSACTIONS PER AREA", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df6.groupby("TRANS_AREA").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["TRANS_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df6['TRANS_AREA'].describe())
#set limits
maxLim=1000000
minLim=min(df6['TRANS_AREA'])-0.4
#barplot horizontal
g=sns.barplot(x='STORE', y ='TRANS_AREA',data=df6)

# %%
#to put the labels
plt.figure(figsize=(20,3))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("NUMBERS OF ITEMS PER AREA IN DIFFERENT STORES", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df6.groupby("AREA_ITEM").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["AREA_ITEM"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df6['AREA_ITEM'].describe())
#set limits
maxLim=1000000
minLim=min(df6['AREA_ITEM'])-0.4
#barplot horizontal
g=sns.barplot(x='STORE', y ='AREA_ITEM',data=df6)

# %%
df7.head(3)
# Out:
#    BU_CODE_STO  CUSTOMER_VISITOR  FOOD_PER_CUSTOMER     STORE_AREA  \
# 0           12          0.557702        1352.556455  355304.250000
# 1           14          0.521411        1606.637081  306497.535714
# 2           17          0.392739        1241.683737  384133.571429
#
#    FOOD_CUSTOMER_RATIO  STORE_AREA_RATIO
# 0             1.089331          4.550053
# 1             1.293964          3.925031
# 2             1.000035          4.919244

# %%
#to put the labels
plt.figure(figsize=(20,3))
plt.ylabel('FOOD_PER_CUSTOMER', fontsize=24)
plt.xlabel('BU_CODE_STO', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("NUMBERS OF ITEMS PER AREA IN DIFFERENT STORES", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df7.groupby("FOOD_PER_CUSTOMER").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["FOOD_PER_CUSTOMER"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df7['FOOD_PER_CUSTOMER'].describe())
#set limits
maxLim=1000000
minLim=min(df7['FOOD_PER_CUSTOMER'])-0.4
#barplot horizontal
g=sns.barplot(x='BU_CODE_STO', y ='FOOD_PER_CUSTOMER',data=df7)

# %%
#to put the labels
import matplotlib.patches as mpatches
##DEFINE SIZE
plt.figure(figsize=(20,12))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("COMPARATIVE STUDY ON CUSTOMER AND VISITOR RATIO, FOOD ITEM PER CUSTOMER AND STORE AREA PER CUSTOMER", fontsize=20)


plt.stackplot(df7["BU_CODE_STO"],[df7["CUSTOMER_VISITOR"],df7["FOOD_CUSTOMER_RATIO"],df7["STORE_AREA_RATIO"]],colors=['#37b85d','#73b837','#adc61b'])
# for colour code
######
plt.legend([mpatches.Patch(color='#37b85d'),  
            mpatches.Patch(color='#73b837'), 
            mpatches.Patch(color='#adc61b')], 
           ['CUSTOMER AND VISITOR RATIO','FOOD CONSUMED PER CUSTOMER','STORE_AREA_RATIO'])
plt.show()

# %%
##DEFINE SIZE
plt.figure(figsize=(18,9))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("COMPARATIVE STUDY ON CUSTOMER AND VISITOR RATIO, FOOD ITEM PER CUSTOMER AND STORE AREA PER CUSTOMER", fontsize=12)


N=20
y1=df7["CUSTOMER_VISITOR"]
y2=df7["FOOD_CUSTOMER_RATIO"]
y3=df7["STORE_AREA_RATIO"]
ind=np.arange(N)
p1=plt.bar(ind,y1)
p2=plt.bar(ind,y2,bottom=y1)
p3=plt.bar(ind,y3,bottom=y2)
plt.ylabel("")
plt.xlabel("bu code")
plt.xticks(ind,df7["BU_CODE_STO"])
plt.legend(['CUSTOMER/VISITOR','FOOD_CUSTOMER_RATIO','STORE_AREA_RATIO'])
plt.show()

# %%
df8.head()
# Out:
#    BU_CODE_STO  INFO_DATE  DAY_WEEK  CUST_VISIT_RATIO  TOTAL_FOOD_SALE  \
# 0           12  01-FEB-19         6          0.591023        198184.83
# 1           14  01-FEB-19         6          0.541878        124062.84
# 2           17  01-FEB-19         6          0.436602         91853.91
# 3           19  01-FEB-19         6          0.490274        163715.85
# 4           20  01-FEB-19         6          0.418843        130033.06
#
#    TOTAL_TRANSACTION  FOOD_RATIO  TRANSACTION_RATIO
# 0        10302848.60    1.981848           1.030285
# 1         4845625.52    1.240628           0.484563
# 2         4495746.84    0.918539           0.449575
# 3         7435204.12    1.637158           0.743520
# 4         4631642.51    1.300331           0.463164

# %%
df9.head()
# Out:
#    BU_CODE_STO  INFO_DATE  DAY_WEEK  CUST_VISIT_RATIO  TOTAL_FOOD_SALE  \
# 0          416  01-FEB-19         6          0.422858        110862.73
# 1          467  01-FEB-19         6          0.369314         95776.11
# 2          470  01-FEB-19         6          0.489362         57356.77
# 3          416  02-FEB-19         7          0.426995        163253.33
# 4          467  02-FEB-19         7          0.357534        117488.24
#
#    TOTAL_TRANSACTION  FOOD_RATIO  TRANSACTION_RATIO
# 0         3770761.55    1.108627           0.377076
# 1         2823203.48    0.957761           0.282320
# 2         2920945.38    0.573568           0.292095
# 3         6400446.55    1.632533           0.640045
# 4         3946564.41    1.174882           0.394656

# %%
##DEFINE SIZE
plt.figure(figsize=(18,6))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('DAY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("STUDY FOR 1ST 1 WEEK", fontsize=12)


N=140
y1=df8.head(140)["CUST_VISIT_RATIO"]
y2=df8.head(140)["FOOD_RATIO"]
y3=df8.head(140)["TRANSACTION_RATIO"]
ind=np.arange(N)
p1=plt.bar(ind,y1)
p2=plt.bar(ind,y2,bottom=y1)
p3=plt.bar(ind,y3,bottom=y2)
plt.ylabel("")
plt.xlabel("DAY")
plt.xticks(ind,df8["DAY_WEEK"])
plt.legend(['CUST_VISIT_RATIO','TOTAL_FOOD_RATIO','TOTAL_TRANSACTION_RATIO'])
plt.show()

# %%
##DEFINE SIZE
plt.figure(figsize=(18,6))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("STUDY FOR LAST 1 WEEK", fontsize=12)


N=140
y1=df8.tail(140)["CUST_VISIT_RATIO"]
y2=df8.tail(140)["FOOD_RATIO"]
y3=df8.tail(140)["TRANSACTION_RATIO"]
ind=np.arange(N)
p1=plt.bar(ind,y1)
p2=plt.bar(ind,y2,bottom=y1)
p3=plt.bar(ind,y3,bottom=y2)
plt.ylabel("")
plt.xlabel("DAY")
plt.xticks(ind,df8["DAY_WEEK"])
plt.legend(['CUST_VISIT_RATIO','TOTAL_FOOD_RATIO','TOTAL_TRANSACTION_RATIO'])
plt.show()

# %%
#to put the labels
plt.figure(figsize=(20,3))
plt.ylabel('CUST_VISIT_RATIO', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("IN STORES TRANSACTIONS PER AREA", fontsize=20)

## set colours to increase with values
sns.set(style="darkgrid")
groupedvalues=df8.groupby("CUST_VISIT_RATIO").sum().reset_index()
pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["CUST_VISIT_RATIO"].argsort().argsort()

#get summary stats of data
summary=pd.DataFrame(df8['CUST_VISIT_RATIO'].describe())
#set limits
maxLim=1000000
minLim=min(df8['CUST_VISIT_RATIO'])-0.4
#barplot horizontal
g=sns.barplot(x='INFO_DATE', y ='CUST_VISIT_RATIO',data=df8)

# %%
df9.head()
# Out:
#    BU_CODE_STO  INFO_DATE  DAY_WEEK  CUST_VISIT_RATIO  TOTAL_FOOD_SALE  \
# 0          416  01-FEB-19         6          0.422858        110862.73
# 1          467  01-FEB-19         6          0.369314         95776.11
# 2          470  01-FEB-19         6          0.489362         57356.77
# 3          416  02-FEB-19         7          0.426995        163253.33
# 4          467  02-FEB-19         7          0.357534        117488.24
#
#    TOTAL_TRANSACTION  TRANS_FOOD_RATIO
# 0         3770761.55          1.700644
# 1         2823203.48          1.473856
# 2         2920945.38          2.546295
# 3         6400446.55          1.960281
# 4         3946564.41          1.679557

# %%
#to put the labels
import matplotlib.patches as mpatches
##DEFINE SIZE
plt.figure(figsize=(20,6))
plt.ylabel('RATIO', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("IN NORTH SWEDEN STORES ", fontsize=20)


plt.stackplot(df9["INFO_DATE"],[df9["CUST_VISIT_RATIO"],df9["TRANS_FOOD_RATIO"]],colors=['#37b85d','#73b837'])
# for colour code
######
plt.legend([mpatches.Patch(color='#37b85d'),  
            mpatches.Patch(color='#73b837'), 
           ], 
           ['CUSTOMER AND VISITOR RATIO','TOTAL TRANSACTION AND FOOD SOLD RATIO'])
plt.show()

# %%
#to put the labels
import matplotlib.patches as mpatches
##DEFINE SIZE
plt.figure(figsize=(20,6))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("NORTH SWEDEN COMPARATIVE STUDY ON CUSTOMER AND VISITOR RATIO, FOOD ITEM PER CUSTOMER AND STORE AREA PER CUSTOMER", fontsize=20)


plt.stackplot(df9["INFO_DATE"],[df9["CUST_VISIT_RATIO"],df9["TRANS_FOOD_RATIO"]],colors=['#37b85d','#73b837'])
# for colour code
######
plt.legend([mpatches.Patch(color='#37b85d'),  
            mpatches.Patch(color='#73b837'), 
           ], 
           ['CUSTOMER AND VISITOR RATIO','FOOD CONSUMED PER CUSTOMER','STORE_AREA_RATIO'])
plt.show()

# %%
#to put the labels
import matplotlib.patches as mpatches
##DEFINE SIZE
plt.figure(figsize=(20,6))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("MIDDLE SWEDEN COMPARATIVE STUDY ON CUSTOMER AND VISITOR RATIO, FOOD ITEM PER CUSTOMER AND STORE AREA PER CUSTOMER", fontsize=20)


plt.stackplot(df10["INFO_DATE"],[df10["CUST_VISIT_RATIO"],df10["TRANS_FOOD_RATIO"]],colors=['#37b85d','#73b837'])
# for colour code
######
plt.legend([mpatches.Patch(color='#37b85d'),  
            mpatches.Patch(color='#73b837'), 
           ], 
           ['CUSTOMER AND VISITOR RATIO','FOOD CONSUMED PER CUSTOMER','STORE_AREA_RATIO'])
plt.show()

# %%
#to put the labels
import matplotlib.patches as mpatches
##DEFINE SIZE
plt.figure(figsize=(20,6))
plt.ylabel('AREA_ITEM', fontsize=24)
plt.xlabel('STORE', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("SOUTH SWEDEN COMPARATIVE STUDY ON CUSTOMER AND VISITOR RATIO, FOOD ITEM PER CUSTOMER AND STORE AREA PER CUSTOMER", fontsize=20)


plt.stackplot(df11["INFO_DATE"],[df11["CUST_VISIT_RATIO"],df11["TRANS_FOOD_RATIO"]],colors=['#37b85d','#73b837'])
# for colour code
######
plt.legend([mpatches.Patch(color='#37b85d'),  
            mpatches.Patch(color='#73b837'), 
           ], 
           ['CUSTOMER AND VISITOR RATIO','FOOD CONSUMED PER CUSTOMER','STORE_AREA_RATIO'])
plt.show()

# %%
x = df11['INFO_DATE']
y = df11['TRANS_FOOD_RATIO']

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,2))

df7 [('CUSTOMER_VIEWER_RATIO')].plot(kind='bar')
plt.title('pi plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("CUSTOMER_VIEWER_RATIO", fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt

#First plot
plt.figure() #figsize and dpi are optional plt.figure(figsize=[3,2], dpi=300) 
plt.plot(array1)

#Second plot
plt.figure()
plt.plot(array2)

plt.show()

# %%
##Create 11 order polynomial model with the variables x and y 

f1 = np.polyfit(x, y, 3)
p1 = np.poly1d(f1)
print(p)
PlotPolly(p1,x,y, 'Length')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-07c17ee3584d> in <module>
#       1 ##Create 11 order polynomial model with the variables x and y
#       2
# ----> 3 f1 = np.polyfit(x, y, 3)
#       4 p1 = np.poly1d(f1)
#       5 print(p)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     539     """
#     540     order = int(deg) + 1
# --> 541     x = NX.asarray(x) + 0.0
#     542     y = NX.asarray(y) + 0.0
#     543
#
# TypeError: can only concatenate str (not "float") to str

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,2))

df7 [('FOOD_PER_CUSTOMER')].plot(kind='bar')
plt.title('pi plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("FOOD_PER_CUSTOMER", fontsize=12)
plt.show()

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,2))

df7 [('STORE_AREA')].plot(kind='bar')
plt.title('pi plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("STORE_AREA", fontsize=12)
plt.show()

# %%
df8.head()
# Out:
#    BU_CODE_STO  INFO_DATE  DAY_WEEK  CUST_VISIT_RATIO  TOTAL_FOOD_SALE  \
# 0           12  01-FEB-19         6          0.591023        198184.83
# 1           14  01-FEB-19         6          0.541878        124062.84
# 2           17  01-FEB-19         6          0.436602         91853.91
# 3           19  01-FEB-19         6          0.490274        163715.85
# 4           20  01-FEB-19         6          0.418843        130033.06
#
#    TOTAL_TRANSACTION
# 0        10302848.60
# 1         4845625.52
# 2         4495746.84
# 3         7435204.12
# 4         4631642.51

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,4))

df8.head(80) [('CUST_VISIT_RATIO')].plot(kind='bar')
plt.title('bar plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("CUSTOMER_VIsit_RATIO", fontsize=12)
plt.show()

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,4))

df8.tail(80) [('CUST_VISIT_RATIO')].plot(kind='bar')
plt.title('bar plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("CUSTOMER_VIsit_RATIO", fontsize=12)
plt.show()

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,4))

df8.head(80) [('TOTAL_FOOD_SALE')].plot(kind='bar')
plt.title('bar plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("TOTAL FOOD SOLD", fontsize=12)
plt.show()

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(18,4))

df8 [('TOTAL_TRANSACTION')].plot(kind='bar')
plt.title('bar plot')
#plt.show()
#labels = (np.array(TOTAL_ITEM.index))
#sizes = (np.array((TOTAL_ITEM / TOTAL_ITEM.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("TOTAL TRANSACTION", fontsize=12)
plt.show()

# %%
X=df8.BU_CODE_STO

# %%
Y=df8.CUST_VISIT_RATIO

# %%
print (X)
print (Y)
# Out:
# 0       12
# 1       14
# 2       17
# 3       19
# 4       20
# 5       53
# 6       70
# 7      106
# 8      109
# 9      122
# 10     248
# 11     268
# 12     398
# 13     416
# 14     445
# 15     467
# 16     468
# 17     469
# 18     470
# 19     471
# 20      12
# 21      14
# 22      17
# 23      19
# 24      20
# 25      53
# 26      70
# 27     106
# 28     109
# 29     122
#       ...
# 530    248
# 531    268
# 532    398
# 533    416
# 534    445
# 535    467
# 536    468
# 537    469
# 538    470
# 539    471
# 540     12
# 541     14
# 542     17
# 543     19
# 544     20
# 545     53
# 546     70
# 547    106
# 548    109
# 549    122
# 550    248
# 551    268
# 552    398
# 553    416
# 554    445
# 555    467
# 556    468
# 557    469
# 558    470
# 559    471
# Name: BU_CODE_STO, Length: 560, dtype: int64
# 0      0.591023
# 1      0.541878
# 2      0.436602
# 3      0.490274
# 4      0.418843
# 5      0.496771
# 6      0.518346
# 7      0.543359
# ...

# %%
X=df8.BU_CODE_STO
Y=df8.CUST_VISIT_RATIO
plt.bar((X),(Y), color='r',width=5)
# Out:
# <BarContainer object of 560 artists>

# %%
plt.show()
