# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Import pandas library
import pandas as pd

# %%
# Read the online file by the URL provides above, and assign it to variable "df"
other_path = "C:\Users\IBM_ADMIN\Desktop\DATA_SCIENCE/py_mba_all_1903.xlsx"

# %%
df = pd.read_excel(other_path)

# %%
df.head(2)
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
#
#   MA_CAT_NAME_EN                         MA_NAME_EN
# 0          Paper                      Wood & Fibers
# 1      Wall Deco  Specific Home Furnishing Business

# %%
print(df.columns)
# Out:
# Index(['BU_CODE', 'DAY_WEEK', 'DAY_HOUR', 'ITEM_NO', 'DESCRIPTION', 'ITEM_QTY',
#        'MA_CAT_NAME_EN', 'MA_NAME_EN'],
#       dtype='object')

# %%
#TO CHECK MISSING DATA. THIS WILL SHOW DATA AS FALSE. and null or NaN as TRUE 
missing_data = df.isnull()

# %%
missing_data.head(4)
# Out:
#    BU_CODE  DAY_WEEK  DAY_HOUR  ITEM_NO  DESCRIPTION  ITEM_QTY  \
# 0    False     False     False    False        False     False
# 1    False     False     False    False        False     False
# 2    False     False     False    False        False     False
# 3    False     False     False    False        False     False
#
#    MA_CAT_NAME_EN  MA_NAME_EN
# 0           False       False
# 1           False       False
# 2           False       False
# 3           False       False

# %%
df.head()
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
# 2       17  TUESDAY          10  30358540  LIL ben 11/12 vit 4s       1.0
# 3       19  SATURDAY         12  50000012  elektroniskt present       1.0
# 4      109  TUESDAY          10  10303365  PHALAENOPSIS krukväx       2.0
#
#   MA_CAT_NAME_EN                         MA_NAME_EN
# 0          Paper                      Wood & Fibers
# 1      Wall Deco  Specific Home Furnishing Business
# 2   Carbon steel       Metal, Plastic & Float glass
# 3        Missing                            Missing
# 4   Green plants  Specific Home Furnishing Business

# %%
#TO CHECK MISSING DATA. THIS WILL SHOW DATA AS FALSE. and null or NaN as TRUE 
df.BU_CODE = 109

# %%
df.head()
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
# 2       17  TUESDAY          10  30358540  LIL ben 11/12 vit 4s       1.0
# 3       19  SATURDAY         12  50000012  elektroniskt present       1.0
# 4      109  TUESDAY          10  10303365  PHALAENOPSIS krukväx       2.0
#
#   MA_CAT_NAME_EN                         MA_NAME_EN
# 0          Paper                      Wood & Fibers
# 1      Wall Deco  Specific Home Furnishing Business
# 2   Carbon steel       Metal, Plastic & Float glass
# 3        Missing                            Missing
# 4   Green plants  Specific Home Furnishing Business

# %%
DF109 = df

# %%
DF109.head()
# Out:
#    TRA_LINE_SEQ_NO  TRA_SEQ_NO  WORKSTATION_ID  BU_CODE BU_TYPE  \
# 0                3           3               1      109     STO
# 1                3           3               1      109     STO
# 2                3           3               1      109     STO
# 3                3           3               3      109     STO
# 4                3           3               3      109     STO
#
#                     TRA_START_TIME TRA_TYPE ENTRY_METHOD  TRA_LINE_START_TIME  \
# 0  02-AUG-18 05.32.08.000000000 PM     SALE      Scanned                  NaN
# 1  01-DEC-18 09.45.53.000000000 AM     SALE        Keyed                  NaN
# 2  02-DEC-18 10.43.26.000000000 AM     SALE          MSR                  NaN
# 3  01-AUG-18 12.18.34.000000000 PM     SALE      Scanned                  NaN
# 4  02-OCT-18 12.39.53.000000000 PM     SALE      Scanned                  NaN
#
#       ITEM_NO      ...      TRANSLINK_WORKSTATION_ID TRANSLINK_BU_CODE  \
# ...

# %%
#TO CHECK MISSING DATA. THIS WILL SHOW DATA AS FALSE. and null or NaN as TRUE 
df.BU_CODE = 109

# %%
df445= df

# %%
df109 = df

# %%
df109.head()
# Out:
#    TRA_LINE_SEQ_NO  TRA_SEQ_NO  WORKSTATION_ID  BU_CODE BU_TYPE  \
# 0                3           3               1      109     STO
# 1                3           3               1      109     STO
# 2                3           3               1      109     STO
# 3                3           3               3      109     STO
# 4                3           3               3      109     STO
#
#                     TRA_START_TIME TRA_TYPE ENTRY_METHOD  TRA_LINE_START_TIME  \
# 0  02-AUG-18 05.32.08.000000000 PM     SALE      Scanned                  NaN
# 1  01-DEC-18 09.45.53.000000000 AM     SALE        Keyed                  NaN
# 2  02-DEC-18 10.43.26.000000000 AM     SALE          MSR                  NaN
# 3  01-AUG-18 12.18.34.000000000 PM     SALE      Scanned                  NaN
# 4  02-OCT-18 12.39.53.000000000 PM     SALE      Scanned                  NaN
#
#       ITEM_NO      ...      TRANSLINK_WORKSTATION_ID TRANSLINK_BU_CODE  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="DAY_HOUR", data=df, color=color[2])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Frequency of order by hour of day", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="DAY_WEEK", data=df, color=color[1])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Frequency of order by hour of day", fontsize=15)
plt.show()

# %%
df.head()
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
# 2       17  TUESDAY          10  30358540  LIL ben 11/12 vit 4s       1.0
# 3       19  SATURDAY         12  50000012  elektroniskt present       1.0
# 4      109  TUESDAY          10  10303365  PHALAENOPSIS krukväx       2.0
#
#   MA_CAT_NAME_EN                         MA_NAME_EN
# 0          Paper                      Wood & Fibers
# 1      Wall Deco  Specific Home Furnishing Business
# 2   Carbon steel       Metal, Plastic & Float glass
# 3        Missing                            Missing
# 4   Green plants  Specific Home Furnishing Business

# %%
# Read the online file by the URL provides above, and assign it to variable "df"
other_path_f = "C:/Users/IBM_ADMIN/Downloads/py_mba_filter_1903_tbr.xlsx"

# %%
df1 = pd.read_excel(other_path_f)

# %%
df1.head()
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
# 2       17  TUESDAY          10  30358540  LIL ben 11/12 vit 4s       1.0
# 3      109  TUESDAY          10  10303365  PHALAENOPSIS krukväx       2.0
# 4      109  WEDNESDAY        11  80402705   DOKUMENT N pennburk       1.0
#
#   MA_CAT_NAME_EN                         MA_NAME_EN
# 0          Paper                      Wood & Fibers
# 1      Wall Deco  Specific Home Furnishing Business
# 2   Carbon steel       Metal, Plastic & Float glass
# 3   Green plants  Specific Home Furnishing Business
# 4   Carbon steel       Metal, Plastic & Float glass

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="MA_NAME_EN", data=df1, color=color[1])
plt.ylabel('Count', fontsize=12)
plt.xlabel('PRODUCT CATEGORY', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("PRODUCT CATEGORY SOLD", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,4))
sns.countplot(x="MA_CAT_NAME_EN", data=df1, color=color[2])
plt.ylabel('Count', fontsize=16)
plt.xlabel('PRODUCT CATAGORY', fontsize=16)
plt.xticks(rotation='vertical')
plt.title("PRODUCT CATAGORY SOLD", fontsize=20)
plt.show()

# %%
df_catagory = df1.groupby('MA_CAT_NAME_EN' , axis = 0).sum()

# %%
df_catagory.head(22)
# Out:
#                                   COUNT
# CATEGORY
# Appliances                         3262
# Bamboo Industrialized              9503
# Candles & Chemicals               99537
# Carbon steel                      93581
# Ceramics                          36086
# Chairs & Hardwood                 33729
# Custom made Worktops                968
# Filled products                   48369
# Foil on Board                     53029
# Furniture fabrics & covers         4208
# Glass, tableware & deco           74322
# Green plants                      64110
# Layer-glued                        2943
# Light Engines & Power Solutions   67829
# Luminaires                        48793
# Mattresses                         9863
# Metals aluminium/Zamak            22160
# Metals stainless steel            89850
# Mirrors & Float glass              4744
# Natural fibres                    10344
# Open & Close                      21515
# Paper                            102755

# %%
df_catagory ['ITEM_QTY'].plot(kind='pie')
plt.title('pi plot')
plt.show()

# %%
plt.figure(figsize=(20,10))
df_catagory ['ITEM_QTY'].plot(kind='pie')
plt.title('pi plot')
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,10))
temp_series = df1['MA_CAT_NAME_EN'].value_counts()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()

# %%
df.head(2)
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
#
#   MA_CAT_NAME_EN                         MA_NAME_EN
# 0          Paper                      Wood & Fibers
# 1      Wall Deco  Specific Home Furnishing Business

# %%
import pandas as pd

# %%
# Read the online file by the URL provides above, and assign it to variable "df"
other_path3 = "C:/Users/IBM_ADMIN/Downloads/CATAGORY.xlsx"

# %%
df2 = pd.read_excel(other_path3)

# %%
df2.head()
# Out:
#                 CATEGORY  COUNT
# 0             Appliances   3262
# 1  Bamboo Industrialized   9503
# 2    Candles & Chemicals  99537
# 3           Carbon steel  93581
# 4               Ceramics  36086

# %%
import pandas as pd

# %%
PI_VAR = df2["COUNT"].astype("int64")

# %%
PI_VAR.head(22)
# Out:
# 0       3262
# 1       9503
# 2      99537
# 3      93581
# 4      36086
# 5      33729
# 6        968
# 7      48369
# 8      53029
# 9       4208
# 10     74322
# 11     64110
# 12      2943
# 13     67829
# 14     48793
# 15      9863
# 16     22160
# 17     89850
# 18      4744
# 19     10344
# 20     21515
# 21    102755
# Name: COUNT, dtype: int64

# %%
#this function is responsible for taking each cell value, not the row count
df_catagory = df2.groupby('CATEGORY' , axis = 0).sum()

# %%
df_catagory.head()
# Out:
#                        COUNT
# CATEGORY
# Appliances              3262
# Bamboo Industrialized   9503
# Candles & Chemicals    99537
# Carbon steel           93581
# Ceramics               36086

# %%
# THIS FUNCTION WILL COUNT THE VALUE OF EACH ROW AND SHOW THE OP, NOT THE ROW COUNT, BUT SHELL VALUE
plt.figure(figsize=(10,10))

df_catagory ['COUNT'].plot(kind='pie')
plt.title('pi plot')
#plt.show()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
#plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d0a287bce834> in <module>
#       5 plt.title('pi plot')
#       6 #plt.show()
# ----> 7 labels = (np.array(temp_series.index))
#       8 sizes = (np.array((temp_series / temp_series.sum())*100))
#       9 #plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=200)
#
# NameError: name 'temp_series' is not defined

# %%
plt.figure(figsize=(10,10))
temp_series = df2['CATEGORY'].value_counts()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()

# %%
grouped_df = df.groupby(["DAY_WEEK", "DAY_HOUR"])["ITEM_QTY"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('DAY_WEEK', 'DAY_HOUR', 'ITEM_QTY')

plt.figure(figsize=(12,6))
sns.heatmap(grouped_df)
plt.title("Frequency of Day of week Vs Hour of day")
plt.show()

# %%
grouped_df = df.groupby(["BU_CODE", "DAY_HOUR"])["ITEM_QTY"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('BU_CODE', 'DAY_HOUR', 'ITEM_QTY')

plt.figure(figsize=(18,6))
sns.heatmap(grouped_df)
plt.title("Frequency of STORE Vs Hour of day")
plt.show()

# %%
grouped_df = df.groupby(["BU_CODE", "DAY_WEEK"])["ITEM_QTY"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('BU_CODE', 'DAY_WEEK', 'ITEM_QTY')

plt.figure(figsize=(18,6))
sns.heatmap(grouped_df)
plt.title("Frequency of STORE Vs DAY OF WEEK")
plt.show()

# %%
df1.head(8)
# Out:
#    BU_CODE   DAY_WEEK  DAY_HOUR   ITEM_NO           DESCRIPTION  ITEM_QTY  \
# 0      109  SUNDAY           15  80395677   FJÄLLA N förvlåda m       1.0
# 1      248  FRIDAY           15  30295656  FISKBO ram 21x30 sva       1.0
# 2       17  TUESDAY          10  30358540  LIL ben 11/12 vit 4s       1.0
# 3      109  TUESDAY          10  10303365  PHALAENOPSIS krukväx       2.0
# 4      109  WEDNESDAY        11  80402705   DOKUMENT N pennburk       1.0
# 5      109  SATURDAY         10  10239280  HEMNES N byrå 8 lådo       1.0
# 6      248  WEDNESDAY        14  17228340  FRAKTA kasse stor 71       1.0
# 7      248  SATURDAY         12  60152590  BJÄRNUM krok hopfäll       1.0
#
#             MA_CAT_NAME_EN                         MA_NAME_EN
# 0                    Paper                      Wood & Fibers
# 1                Wall Deco  Specific Home Furnishing Business
# 2             Carbon steel       Metal, Plastic & Float glass
# ...

# %%
grouped_df = df1.groupby(["BU_CODE", "MA_CAT_NAME_EN"])["ITEM_QTY"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('BU_CODE', 'MA_CAT_NAME_EN', 'ITEM_QTY')

plt.figure(figsize=(24,6))
sns.heatmap(grouped_df)
plt.title("Frequency of STORE Vs ITEM_CATAGORY")
plt.show()

# %%
grouped_df = df1.groupby(["MA_CAT_NAME_EN", "DAY_HOUR"])["ITEM_QTY"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot('MA_CAT_NAME_EN', 'DAY_HOUR', 'ITEM_QTY')

plt.figure(figsize=(18,6))
sns.heatmap(grouped_df)
plt.title("HOUR OF DAY Vs ITEM")
plt.show()

# %%
plt.figure(figsize=(10,10))
temp_series = df1['MA_CAT_NAME_EN'].value_counts()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()
